# %% [markdown]
# ## Getting text data from youtube videos
#
# ### Overview
#
# This workbook provides a short illustration of how to download the transcripts for a series of youtube videos, store them in pandas dataframes, and run a few queries to show the kind of analysis you may be interested in doing in your own research.
#
# ### Software
#
# This workbook uses the following modules.
#
# * Pandas
# * PandaSQL
# * youtube_transcript_api
#
# ### Background
#
# In my consulting sessions with researchers, I've been getting more questions lately about how to extract text with time stamps from videos and images. This makes a certain amount of sense, with the amount of public data now posted online.
#
# Youtube often provides a text transcript (captions) along with time stamps. You can access this transcript without any programming through the youtube website. Here are instructions:
#
# https://ccm.net/faq/40644-how-to-get-the-transcript-of-a-youtube-video
#
# If you have a large number of videos, you may want to avoid a lot of manual downloading and formatting and use a python script. Fortunately, an open source module, "youtube_transcipt_api", provides an easy API for this task.
#
# https://pypi.org/project/youtube-transcript-api/
#
#
# #### Note - Getting text data from my own videos
#
# If you have videos and don't mind making them public or unlisted, you can use this approach by uploading them to youtube and using the methods here. If you have a very large dataset, you might want to use a cloud storage and API solution. Various platforms provide this - here's a link to the google API.
#
# https://cloud.google.com/video-intelligence/docs/text-detection
#
# This takes a little more programming and configuration, and may result in some cloud computing charges depending depending on the amount of data you want to process, but it is probably more scalable and can offer a more secure environment for videos you want to keep private.

# %% [markdown]
# ### Sample Data
#
# This workbook reads the text from a series of youtube videos,
# formats them in a python dataframe, and queries them by timestamp and text strings.
#
# For illustration, we'll use a series of lectures from "On Power and Politics in Today's World"
#
# https://www.youtube.com/playlist?list=PLh9mgdi4rNeyViG2ar68jkgEi4y6doNZy"

# %% [markdown]
# ### Install and import the youtube_transcript_api
#
# You'll need to install the module before you can import it. You only have to do this once on your system (even if you use it in a different notebook or python script), so you may want to comment out or remove this line after running it once.

# %%
#!pip install youtube_transcript_api

# %%
from youtube_transcript_api import YouTubeTranscriptApi
import pandas as pd

# %%
pd.options.display.max_columns = None
pd.options.display.max_rows = None
pd.options.display.max_colwidth = None

# %% [markdown]
# ### Extract the transcript from one video
#
# We'll extract the transcript for each video using the YouTubeTransciptAPI get_transcript() method. This method takes the video ID as a parameter.
#
# You can get the video ID from the URL on youtube - for example, https://www.youtube.com/watch?v=BDqvzFY72mg has the ID 'BDqvzFY72mg'

# %%
transcript = YouTubeTranscriptApi.get_transcript('BDqvzFY72mg')

# %% [markdown]
# The method returns the transcript of the video as a list of lines, each stored as a dictionary. We get 1280 lines from the video above.

# %%
print(type(transcript))
print(len(transcript))
# Out:
# <class 'list'>
# 912

# %% [markdown]
# Let's look at the first few lines. Each line contains a dictionary with keys "text", "start", and "duratation".

# %%
transcript[:3]
# Out:
# [{'text': '- Hello everybody and welcome.', 'start': 8.06, 'duration': 2.66},
#  {'text': 'How is everybody today?', 'start': 10.72, 'duration': 1.613},
#  {'text': 'Great.', 'start': 13.404, 'duration': 0.916}]

# %% [markdown]
# You can parse the video using standard techiques for JSON or dictionaries (more info here: https://github.com/geoffswc/Python-JSON-Workshop).

# %% [markdown]
# ### Transcripts for Multiple Videos in Pandas Format
#
# Fortunately, this is a flat dictionary structure, not deeply nested, so we can convert this to a pandas dataframe easily. In this next section, we'll review code to convert a series of videos and concatenate them into a single data frame.

# %% [markdown]
# First, we'll greate a list of IDs for each video.

# %%
links = [
    'BDqvzFY72mg',
    'f5nbT4xQqwI',
    's48b9B5gd88',
    '4eUS8trd_yI',
    'aKW_Vsk4hzs',
    'q53DF6ySOZg',
    'T3-VlQu3iRM'
]

# %% [markdown]
# Extract the transcript for each video using the YouTubeTransciptAPI get_transcript() method.
#
# For now, we will store the transcript for each video in a list named transcripts.

# %%
transcripts = []
for v in links:
    try:
        df = pd.DataFrame(YouTubeTranscriptApi.get_transcript(v))
        df['video_id'] = v
        transcripts.append(df)
    except:
        print(v, 'failed to translate')
# Out:
# aKW_Vsk4hzs failed to translate

# %% [markdown]
# Note that we have now created a list of pandas dataframes. Let's take a look at a few lines from the first one.

# %%
transcripts[0].head()
# Out:
#                                            text   start  duration     video_id
# 0                - Hello everybody and welcome.   8.060     2.660  BDqvzFY72mg
# 1                       How is everybody today?  10.720     1.613  BDqvzFY72mg
# 2                                        Great.  13.404     0.916  BDqvzFY72mg
# 3  Well, I'm delighted to\nhave the opportunity  14.320     3.540  BDqvzFY72mg
# 4             to be giving the DeVane Lectures.  17.860     2.920  BDqvzFY72mg

# %% [markdown]
# Next, we'll combine all the dataframes into a single dataframe.

# %%
df_transcripts = pd.concat(transcripts).reset_index(drop=True)

# %%
#df_transcripts.iloc[1000:1100]

# %% [markdown]
# ### Run some queries
#
# Now that we have our text in a single dataframe, we can analyze it using a wide range of tools in python. You might be interested in natural language processing, sentiment analysis, text classification, lexical structures, regional differences in language ussed in school board meeings... more than we can get into here (though feel free to get started here with the Library "Document Classification with Scikit-Learn" workshop aat https://courses.ucsf.edu/course/view.php?id=8249)
#
# For now, we'll just query the data in a few ways and leave it there. If you've taken any of my workshops, you'll know I lean toward using SQL, so I'll write a very queries using the pandasql module.

# %%
# !pip isntall pandasql 
from pandasql import sqldf 
pysqldf = lambda q: sqldf(q, globals())

# %%
# which videos have the most lines of text
pysqldf("SELECT video_id, COUNT(*) FROM df_transcripts GROUP BY video_id")
# Out:
#       video_id  COUNT(*)
# 0  4eUS8trd_yI      1300
# 1  BDqvzFY72mg       912
# 2  T3-VlQu3iRM      1280
# 3  f5nbT4xQqwI      1180
# 4  q53DF6ySOZg      1380
# 5  s48b9B5gd88      1286

# %%
# which videos were longest (highest timestamp + duration)
pysqldf("SELECT video_id, MAX(start + duration) FROM df_transcripts GROUP BY video_id")
# Out:
#       video_id  MAX(start + duration)
# 0  4eUS8trd_yI               4325.166
# 1  BDqvzFY72mg               3367.023
# 2  T3-VlQu3iRM               4234.644
# 3  f5nbT4xQqwI               4235.705
# 4  q53DF6ySOZg               4399.389
# 5  s48b9B5gd88               4423.037

# %%
# Most mentions of the Cold War
pysqldf("""
SELECT 
    video_id, 
    COUNT(1) 
FROM 
    df_transcripts 
WHERE 
    LOWER(text) LIKE ('%cold war%')
GROUP BY 
    video_id""")
# Out:
#       video_id  COUNT(1)
# 0  BDqvzFY72mg         8
# 1  T3-VlQu3iRM         1
# 2  f5nbT4xQqwI         2
# 3  q53DF6ySOZg         4
# 4  s48b9B5gd88        19

# %%
# what rows matched
pysqldf("""
SELECT 
    *
FROM 
    df_transcripts 
WHERE 
    LOWER(text) LIKE ('%cold war%')
""")
# Out:
#                                                            text     start  \
# 0                                      because of the Cold War.   113.460
# 1                     most of the conflicts within the Cold War   123.260
# 2       at the end of the Cold War\nit was a defensive alliance  1828.730
# 3               that came about as a\nbyproduct of the Cold War  2001.730
# 4                                           since the Cold War.  3106.630
# 5                              who are both cold war historians  3120.300
# 6           who are gonna be teaching\ncourses on the Cold War.  3122.480
# 7          from into war Europe II to\nthe end of the Cold War,  3130.600
# 8                  We had arms races all\nthrough the Cold War,  1296.080
# 9      but we're not, this is not\na course about the Cold War.  1582.250
# 10          of what I'm calling the\nearly post-Cold War world,    12.910
# 11                     about NATO expansion after the Cold War,    45.860
# 12                             like when the Cold War collapses   402.280
# 13         or not out there but in\nthe middle of the Cold War,   411.090
# 14                So let's think about\nthe first post-Cold War   436.980
# 15                                  of the post-Cold War world.   868.350
# 16                       So NATO is a creature of the Cold War.   909.000
# 17                          was successful during the Cold War.  1488.730
# 18                You could say, well,\nthe US won the Cold War  1491.970
# 19        whether we could have won\nthe Cold War without NATO.  1509.300
# 20       during the Cold War, never\nactually went into battle.  1516.960
# 21             was in Kosovo in 1999,\nafter the Cold War over.  1527.090
# 22                                 in the post-Cold War period,  1543.070
# 23                                  So NATO after the Cold War.  1574.670
# 24         at the end of the Cold War\nbecause of East Germany.  1603.360
# 25              finally erasing the\nboundary line the Cold War  1802.380
# 26                               since the end of the Cold War.  1856.590
# 27                                     about post-Cold War NATO  2602.170
# 28  Was there a missed opportunity\nat the end of the Cold War?  2610.290
# 29                                     the end of the Cold War,   952.980
# 30           or would start to diminish\nas the Cold War ended.  1128.164
# 31              would start to diminish\nas the Cold War ended.  1142.301
# 32                                 that the end of the Cold War  1448.402
# 33      in this new world that has\nemerged since the Cold War.  4213.110
#
#     duration     video_id
# 0      1.490  BDqvzFY72mg
# 1      3.460  BDqvzFY72mg
# 2      2.370  BDqvzFY72mg
# 3      0.833  BDqvzFY72mg
# 4      1.740  BDqvzFY72mg
# 5      2.180  BDqvzFY72mg
# 6      3.240  BDqvzFY72mg
# 7      5.000  BDqvzFY72mg
# 8      2.730  f5nbT4xQqwI
# 9      3.543  f5nbT4xQqwI
# 10     4.050  s48b9B5gd88
# 11     3.750  s48b9B5gd88
# 12     2.170  s48b9B5gd88
# 13     3.430  s48b9B5gd88
# 14     5.000  s48b9B5gd88
# 15     2.660  s48b9B5gd88
# 16     4.393  s48b9B5gd88
# 17     2.253  s48b9B5gd88
# 18     2.510  s48b9B5gd88
# 19     4.550  s48b9B5gd88
# 20     3.370  s48b9B5gd88
# 21     4.250  s48b9B5gd88
# 22     2.270  s48b9B5gd88
# 23     2.893  s48b9B5gd88
# 24     3.713  s48b9B5gd88
# 25     2.860  s48b9B5gd88
# 26     3.113  s48b9B5gd88
# 27     2.170  s48b9B5gd88
# 28     5.000  s48b9B5gd88
# 29     1.830  q53DF6ySOZg
# 30     4.539  q53DF6ySOZg
# 31     4.499  q53DF6ySOZg
# 32     1.828  q53DF6ySOZg
# 33     5.000  T3-VlQu3iRM

# %%
# when was cold war first mentioned in each video?
pysqldf("""
SELECT 
    video_id, 
    MIN(start) 
FROM 
    df_transcripts 
WHERE 
    LOWER(text) LIKE ('%cold war%')
GROUP BY 
    video_id""")
# Out:
#       video_id  MIN(start)
# 0  BDqvzFY72mg      113.46
# 1  T3-VlQu3iRM     4213.11
# 2  f5nbT4xQqwI     1296.08
# 3  q53DF6ySOZg      952.98
# 4  s48b9B5gd88       12.91

# %%
#aKW_Vsk4hzs
transcript = pd.DataFrame(YouTubeTranscriptApi.get_transcript('q53DF6ySOZg'))

# %%
transcript
# Out:
#                                                                text     start  \
# 0                                                 - Okay, so today,     7.130
# 1             we're talking about the\nresurgent right in the West.     8.270
# 2                                      Let's get fix our intuitions    12.590
# 3                              with a little walk down memory lane.    14.580
# 4                                     - [Ronald Reagan] In Chicago,    21.290
# 5                          they found a woman who holds the record.    22.160
# 6            She used 80 names, 30\naddresses, 15 telephone numbers    24.550
# 7                          to collect food stamps, social security,    28.876
# 8                          veteran's benefits for four non-existent    31.817
# 9                   deceased veterans husbands\nas well as welfare.    34.760
# 10                                   Her tax free cash income alone    38.330
# 11                                has been running $150,000 a year.    40.920
# 12                                      - So that was Ronald Reagan    46.040
# 13                            running for the Republican nomination    48.050
# 14                                     against Gerald Ford in 1976,    52.040
# 15                                       which he was unsuccessful,    57.552
# 16                     and that's his famous\nwelfare queens speech    59.391
# 17                                               which would become    62.860
# 18              if things had been able\nto go viral in those days,    64.267
# 19                       it did the paper equivalent of going viral    68.060
# 20                          and it represented this frontal assault    72.431
# 21                                            on the welfare state,    76.180
# 22                        on what might be more broadly referred to    77.671
# 23                     as the postwar consensus\nthat had prevailed    80.880
# 24    in almost all of the capitalist\ndemocracies since the 1950s.    85.030
# 25             In the US, it went by the\nname of the Great Society    91.549
# 26                                     ushered in by Lyndon Johnson    95.626
# 27                which was not only the\ncivil rights legislation,    98.100
# 28                                    but the creation of Medicare,   101.889
# 29                        considerable expansion of many components   104.983
# 30                                            of the welfare state.   110.010
# 31             In Britain, it was of course\nthe postwar government   112.230
# 32                     of Clement Attlee voted\ninto office in 1945   115.430
# 33                           that put into place the major elements   120.443
# 34                                    of the British welfare state.   123.296
# 35                  And in many of the\nEuropean social democracies   126.037
# 36                                       as they came to be called,   130.028
# 37             we got countries that were\nmarked by strong welfare   132.190
# 38                            and other forms of social protections   140.100
# 39                                        such as health insurance,   142.530
# 40                                unemployment insurance, pensions,   144.280
# 41                                         progressive tax systems,   147.578
# 42                 a lot of redistribution\nthrough the tax system,   149.960
# 43                        much more steeply progressive tax systems   152.820
# 44                            than in any of those countries today.   155.510
# 45                                        And it's important to say   158.281
# 46                     that the support for\nthis postwar consensus   161.220
# 47                                    was substantially bipartisan.   163.900
# 48                                       So for example, in Britain   166.144
# 49                           when the Conservatives under Churchill   168.279
# 50                                    came back into power in 1951,   174.020
# 51                  many people said, "Oh,\nthey're gonna roll back   177.350
# 52                                "everything that labor has done."   179.764
# 53                                        Not a bit of it actually.   182.144
# 54                                           They even expanded it.   183.820
# 55                  And through much of the\n1950s, '60s, and '70s,   186.010
# 56          you saw in most countries\nthe recognition of a kind of   191.036
# 57            what seemed to be a\nsubstantially bipartisan support   195.630
# 58                                          for this welfare state.   201.961
# 59                          In the US, in the Nixon Administration,   204.540
# 60             of course, there was some\npressure for lower taxes,   208.406
# 61              but still, much of the\nwelfare state was preserved   212.880
# 62                           and in some ways it was even expanded.   216.330
# 63                                            They got things like,   219.480
# 64                which I'll be talking\nabout later in the course,   220.928
# 65                                  such as universal basic income.   223.400
# 66       Nixon has supported what he\ncalled a negative income tax,   227.100
# 67                                 a kind of refundable tax credit.   230.410
# 68       We've ended up getting something\nthat's a cousin of that.   232.860
# 69                              In Europe in countries like Germany   237.416
# 70                           where they have coalition governments,   242.570
# 71                                            in the '60s and '70s,   244.816
# 72          they were basically dominated\nby the social democrats.   247.630
# 73                   First, Willy Brandt,\nand then Helmut Schmidt.   251.290
# 74                                         After in the early '80s,   255.605
# 75                   for reasons we'll be\ntalking about next time,   259.227
# 76                                  the social democrats got weaker   261.900
# 77                       and Helmut Kohl's Conservatives took over.   263.830
# 78                                                But it was still,   266.620
# 79                               there was very substantial support   268.427
# 80    for European social democracy\nacross the political spectrum.   270.945
# 81           For example, in the '60s\nand '70s in France and Italy   276.740
# 82                    where Communist parties\nhad been very strong   280.420
# 83                                       and had traditionally been   283.596
# 84                           more Stalinist like Communist parties,   285.690
# 85                             we had the advent of Euro-Communism.   288.360
# 86                                         What was Euro-Communism?   291.800
# 87                                          Well, one feature of it   293.359
# 88                   was that it was denounced\nby the Soviet Union   295.196
# 89                                     as revisionist deviationism.   299.090
# 90                         And the other was that the standing joke   302.845
# 91                 in Italy in the 1970s\nwas how can you tell that   305.113
# 92                which is the Communist\npolitician in parliament?   309.940
# 93       How do you tell the Communist\nfrom the other politicians?   313.390
# 94      And the answer was because\nthey have more expensive suits.   316.420
# 95             So the Euro-Communists\nagain stop pushing this idea   320.670
# 96                          that social democracy was a way station   325.410
# 97                             on the way to Soviet style Communism   328.284
# 98                                and instead was a particular form   332.356
# 99     of political and social\norganization that had come to stay.   335.836
# 100                                And it was seen to be as I said,   341.530
# 101                                        a very broad bipartisan,   345.936
# 102                          or in Europe, multipartisan consensus.   349.420
# 103                   And this is what starts\nto come under attack   352.280
# 104                               in the late 1970s and early 1980s   355.283
# 105                                  that Reagan is taking dead aim   360.870
# 106                                  at the heart of that consensus   364.030
# 107      and the new attack is marked\nby hostility to trade unions   367.416
# 108                                          and the welfare state.   372.643
# 109                          It's hostility to progressive taxation   374.720
# 110                                    and hostility to regulation,   379.864
# 111                    the sort of forerunner\nof the neoliberalism   382.300
# 112                                     that would be coming later.   385.440
# 113                               And as in Reagan's famous slogan,   387.510
# 114                government is not the\nsolution to our problems.   390.610
# 115                                      Government is the problem.   393.883
# 116       We have to weaken the power\nof government in the economy   396.280
# 117                                         and let the market run.   400.475
# 118                                         This is the basic idea.   404.854
# 119                          Now, the first thing to say about this   407.635
# 120                                      is when people like Reagan   410.630
# 121                            and Thatcher came into power in the,   413.540
# 122             Reagan got selected in\n1980, in the 1980 election.   416.880
# 123                       Margaret Thatcher comes to power in 1979.   422.430
# 124                                     She had beaten Edward Heath   426.690
# 125                  for the Conservative\nParty leadership in 1975   430.690
# 126                 in the first competitive\nelection for a leader   434.530
# 127                        in the Conservative Party in its history   438.130
# 128                           and people were quite stunned by this   440.207
# 129                           and she'd been thought to be a minor,   442.880
# 130                                    second tier cabinet official   447.400
# 131                               without much future in the party.   449.320
# 132                        And indeed, I think it was Geoffrey Howe   452.690
# 133                          who said she'll be gone in six months.   454.780
# 134                                       Turned out she was leader   457.360
# 135                          of the Conservative Party for 15 years   458.450
# 136                    and Prime Minister for\n11 and a half years.   460.950
# 137                  But I think it's fair\nto say that most people   464.990
# 138                    did not take Reagan\nand Thatcher seriously.   469.341
# 139                                  They saw them as real threats,   472.987
# 140                           but most people in the establishment,   475.300
# 141           the political establishment,\nthe economic establish,   478.271
# 142               didn't take them seriously\nas long term threats.   481.827
# 143                                 Those people tended to see this   485.840
# 144                               as a kind of aberrational outcome   488.120
# 145                         and that things would revert to normal.   491.870
# 146                Social democracy was\nabout alternation in power   495.020
# 147                  between center right\nand center left parties,   497.720
# 148                             and this was a center right moment,   500.620
# 149                                        but things would revert.   502.507
# 150                             There were a few discordant voices.   505.250
# 151                       In the US perhaps, the most prescient one   507.870
# 152       was a man by the name of Kevin\nPhilips who wrote a book,   510.430
# 153                                        published a book in 1969   514.040
# 154                    called "The Emerging\nConservative Majority"   516.528
# 155                            predicting the rise of the new right   519.970
# 156                           in pretty much the form that it took.   522.970
# 157                                                  But he wasn't,   525.740
# 158                              he was later on given great credit   527.466
# 159                                      for having predicted this,   530.050
# 160                                          but for the most part,   531.780
# 161                                              for the most part,   534.970
# 162              people did not see this\nas any kind of sea change   535.960
# 163                         or fundamental realignment of politics.   540.050
# 164                        And just to give you a sense in Britain.   543.240
# 165                  In 1980, the principle\nintellectual architect   546.293
# 166                  of Thatcher's revolution\nwas Sir Keith Joseph   553.878
# 167                      and he was her trade and industry minister   558.032
# 168                and he was the source of\nall her economic ideas   561.910
# 169                          about monetarism and cutting spending.   565.260
# 170                                        And here is Michael Foot   568.740
# 171     who is by then the leader of\nthe Labor Party in opposition   570.590
# 172             commenting on Keith Joseph\nin the House of Commons   574.920
# 173                       just to give you a sense of how seriously   577.980
# 174                      they really took the threat from Thatcher.   580.340
# 175                         - [Michael] I wouldn't like to miss out   586.110
# 176                                  the right honorable gentleman,   587.230
# 177                             the Secretary of State for Industry   588.960
# 178         who's had such a tremendous\neffect upon the government   591.200
# 179                                    and our politics altogether.   596.343
# 180                And as I see the right\nhonorable late gentleman   598.340
# 181                    walking around the\ncountry looking puzzled,   601.827
# 182                    and forlorn, and\nwondering what's happened,   605.280
# 183                                             (audience laughing)   608.808
# 184             I've often tried to remember\nwhat he reminds me of   611.570
# 185                                and the other day, I hit upon it   616.090
# 186                               because I recall that in my youth   619.142
# 187                                  when I used to go in Plymouth,   622.220
# 188                                  yes, I know, quite a time ago.   624.500
# 189                                             (audience laughing)   626.820
# 190                        You'll come to that one in a moment too.   627.734
# 191                       But I used to go when I lived in Plymouth   629.870
# 192                                            every Saturday night   631.770
# 193                                     along to the Palace Theater   633.440
# 194                  and the favorite I always\nused to watch there   636.329
# 195                                         was a magician conjurer   639.483
# 196                           and they used to have in the audience   642.305
# 197                         dressed up as one of the most prominent   645.100
# 198                                           alderman in the place   647.361
# 199          a person who was sitting at\nthe back of the audience.   649.690
# 200                   And the magician conjurer\nwould come forward   652.230
# 201               and say that he wanted\nto have from the audience   655.020
# 202                                              a beautiful watch.   658.376
# 203                           And he would go amongst the audience.   661.257
# 204                                      He'd go up to the alderman   663.150
# 205            and eventually take off\nhim a marvelous gold watch.   664.560
# 206                   And he'd bring it right\nback onto the stage.   668.981
# 207                He'd enfold it in a\nbeautiful red handkerchief.   671.909
# 208                He placed it on the table\nthere in front of us.   675.295
# 209                            He took up his mallet and he hit it!   678.860
# 210                                         Smashed to smithereens!   682.438
# 211                          And then on his countenance would come   686.156
# 212              exactly the puzzled look\nof the right honorable--   690.320
# 213                                             (audience laughing)   692.616
# 214                                      And he would step forward,   694.220
# 215                                      and he would step forward.   703.072
# 216                            He would step forward right 'til he,   708.410
# 217              he'd step forward right\nto the front of the stage   710.807
# 218                                  and he'd say, "I'm very sorry.   712.947
# 219                                                "I'm very sorry.   715.952
# 220                         "I've forgotten the rest of the trick."   717.367
# 221                                             (audience laughing)   719.005
# 222                         That's the situation of the government.   724.597
# 223                         That's the situation of the government.   728.060
# 224                        They've forgotten the rest of the trick.   729.510
# 225                                                 It doesn't work   732.354
# 226                        and unless any objector might come along   733.465
# 227                           and suggest that it was only a trick,   736.979
# 228           I can assure that at the\nPalace Theater in Plymouth,   738.930
# 229                                          the way it was played,   742.310
# 230               he used to come along at\nthe end of the very act   743.440
# 231                                       and say, "I'm very sorry.   745.300
# 232                               "I've still forgotten the trick."   747.407
# 233                           That's the situation in this country.   749.496
# 234         - So there was Michael Foot\nmaking fun of Keith Joseph   751.970
# 235         as a kind of buffoon who\ndidn't know what he was doing   755.670
# 236           and getting lots of positive\nreinforcement for that,   759.520
# 237            but of course, the joke\nreally was on Michael Foot.   764.190
# 238                                              Three years later,   767.020
# 239                he ran unsuccessfully\nagainst Margaret Thatcher   768.520
# 240                           and his election manifesto was called   772.220
# 241                             the longest suicide note in history   775.610
# 242                                     subsequently by historians.   778.120
# 243                                  So the joke was really on Foot   780.680
# 244             and he completely\nunderestimated the staying power   782.820
# 245                               of what was coming down the pike.   787.818
# 246                                      So that's our agenda today   791.940
# 247           and we're gonna look at the\nsources and implications   794.257
# 248                        of the resurgence of right wing politics   797.347
# 249                                 across the Western democracies.   801.350
# 250                So we're gonna look at\nseveral sources of this,   804.452
# 251                            one being the collapse of Communism,   807.900
# 252                                                the second being   810.154
# 253                embedded in the logic of\ndistributive politics,   811.510
# 254                                             and the third being   814.769
# 255                   the changing power\nrelations in the economy.   816.410
# 256                And all three of these\nthings have an influence   820.360
# 257                                     or should have an influence   823.470
# 258              on how we think about the\nresurgence of the right   824.606
# 259                                 and its political implications.   828.210
# 260            And when we think about\nits political implications,   831.065
# 261                I'm gonna talk briefly\ntoday but more next time   834.443
# 262                  about those implications\nin two-party systems   838.229
# 263                                         like Britain and the US   841.440
# 264                                    versus in multiparty systems   843.220
# 265                   where like we have on\nmuch of the continent.   845.263
# 266                                So, let's start with the effects   850.325
# 267                                   of the collapse of Communism.   855.500
# 268                                         When the wall came down   857.750
# 269              and when the Soviet Union\nstarted disintegrating,   859.350
# 270           many, many intellectuals\nand analytical commentators   864.180
# 271                                 thought that this would be good   869.700
# 272                               for European parties on the left.   871.170
# 273                                          They thought generally   874.060
# 274                          that it would be good for two reasons.   875.464
# 275           One, it made it clear that\nEuropean social democracy   880.080
# 276                          or what we think of as a great society   885.580
# 277                             kind of political economy in the US   887.770
# 278                              is not a way station on the future   896.740
# 279            to some either more statused,\nif you like, outcome.   898.800
# 280                                      That once we'd think of it   905.120
# 281                       rather as a kind of permanent equilibrium   907.410
# 282                           that can be defended on its own terms   910.416
# 283     and is not something that's\ngonna produce something worse.   913.690
# 284                  Another way of putting\nperhaps the same point   920.550
# 285                          is it gets rid of the kind of bogeyman   923.078
# 286                             to mobilize against from the right.   926.330
# 287                                 So you know that if you propose   928.860
# 288                        slight increases in progressive taxation   933.053
# 289                                      or you improve healthcare,   936.590
# 290                          the notion of that you're trying to do   938.712
# 291                       is create Communism becomes less credible   940.714
# 292           if there's no Communism in\nthe world left to create.   945.730
# 293   And many people thought that\nwith the Communist threat gone,   949.990
# 294                                        the end of the Cold War,   952.980
# 295                                    we wouldn't need to mobilize   954.810
# 296                               against the Soviet Union anymore,   956.900
# 297     that all of the money that had\nbeen spent on the arms race   958.980
# 298                could be plowed back into\nthe Western economies   963.640
# 299                and we were in for a\ncontinuation, if you like,   968.652
# 300                                  of the benign social democracy   972.744
# 301    and maybe the power would shift\nonce more back to the left.   976.127
# 302                                Maybe the right wing governments   980.600
# 303                                   in say in Britain and the US,   984.624
# 304              or the fact that power in\nGermany had now shifted   987.660
# 305        as I already said from the\nsocial democrats to the CDU,   990.950
# 306                                      maybe it would shift back.   995.730
# 307       And what all of that failed\nto take account of was that,   999.180
# 308    and this is really the story\nof Tony Judt's book "Postwar,"  1005.843
# 309                         some of which I've put on the syllabus,  1010.150
# 310     is that the social democratic\neconomies and welfare states  1012.910
# 311                       depended on a very fortuitous arrangement  1018.316
# 312                                       of demographic, economic,  1021.610
# 313                  and geopolitical\ncircumstances after the war.  1024.000
# 314                                         The demographic one was  1028.057
# 315                        that you had big working age populations  1030.120
# 316                relative to what we call\ndependent populations.  1032.770
# 317                                We think of the dependency ratio  1036.283
# 318                       is the ratio of working age to dependent.  1039.500
# 319                   And dependent is defined\nunder the age of 15  1042.820
# 320                                        and above the age of 65.  1045.810
# 321                              And of course, what really matters  1049.480
# 322                    from the point of view\nof the fiscal health  1051.730
# 323                         of the welfare state is the older crowd  1054.530
# 324        because parents mostly\ninternalize the cost of children  1056.690
# 325                                     whereas governments in turn  1060.121
# 326                        have to bear the cost of elderly people.  1062.260
# 327               And for the most part in\nall of these countries,  1065.360
# 328                                  we had big working populations  1069.220
# 329                       and relatively small elderly populations.  1071.690
# 330                      That would change as the baby boomer bulge  1074.826
# 331                          worked its way through the population.  1078.655
# 332                 And so there's one big\nsource of fiscal stress  1081.880
# 333                       inexorably coming at all of these systems  1085.607
# 334                                  as the ratio of working people  1088.540
# 335                               to retired people would increase.  1091.415
# 336                      Then secondly, much of the economic health  1095.290
# 337                              of these countries had been result  1098.408
# 338            of the enormous infusion\nof funds by the Americans,  1101.565
# 339                                    the Marshall Plan in Europe,  1105.990
# 340                         the rebuilding of the Japanese economy,  1107.690
# 341               and the fact that as I\nmentioned to you earlier,  1110.302
# 342               Europe was not spending\nmoney on its own defense  1114.209
# 343    so it had the resources to\nbuild up its domestic economies.  1117.353
# 344                                      And that too would go away  1126.170
# 345              or would start to diminish\nas the Cold War ended.  1128.164
# 346      Also, the American interest\nin sustaining these economies  1134.156
# 347                           as bulwarks against the Soviet system  1138.706
# 348                 would start to diminish\nas the Cold War ended.  1142.301
# 349                      So the idea that European social democracy  1146.800
# 350   was sort of a permanent equilibrium\nwas by no means obvious.  1150.280
# 351                               It's certainly not in retrospect.  1155.074
# 352                                        A second thing to notice  1157.840
# 353                         is that while the bogeymen of Communism  1159.610
# 354       might not have been there\naround which the Conservative,  1162.794
# 355                           the ideological right could organize,  1166.334
# 356                       there are always other potential bogeymen  1169.250
# 357                and particularly as it's\nturned out since 9/11,  1171.760
# 358              Islamic fundamentalism is\nan alternative bogeyman  1174.871
# 359                   around which to organize\npolitical movements  1178.700
# 360                                  and it has the added advantage  1182.770
# 361               that it's not a threat\nto Democratic capitalism.  1185.007
# 362                                You know, when Islamist regimes,  1189.388
# 363                                 when Islamists do come to power  1191.673
# 364                   whether it's in Iran\nor Libya under Gaddafi,  1194.330
# 365                              they run capitalist systems badly.  1200.559
# 366                                         There's no alternative.  1203.600
# 367                       There's no Islamist model of the economy.  1205.170
# 368                   So the idea that one\nhas to worry about them  1208.310
# 369                                       as a threat to capitalism  1214.990
# 370                in a way that Communism\nhad once been perceived  1216.551
# 371                                             is no longer there.  1220.375
# 372       And that's important because\nit diminishes the incentive  1222.340
# 373                            to buy off working class discontent.  1226.080
# 374                                          So if you think about,  1229.452
# 375                                        go back to the new deal,  1233.620
# 376                                           after the Depression,  1235.242
# 377                  Communist Party in the\nUS was quite powerful.  1237.180
# 378                       It's very influential in American unions,  1239.510
# 379                                        particularly in the CIO.  1241.730
# 380                                        We had 20% unemployment.  1243.470
# 381         There was real fear in the\naftermath of the Depression  1246.775
# 382                    that Communism might\nclaim hearts and minds  1252.018
# 383                            of large numbers of American workers  1257.720
# 384              and that is partly what\nmotivated business elites  1260.472
# 385           and others to at least\ntacitly support the new deal.  1266.150
# 386                       The notion was that you want to make sure  1271.400
# 387              America's workers do not\nreach a state of affairs  1274.709
# 388   where they think they have\nnothing to lose but their chains.  1280.934
# 389                               And so my colleague Peter Swenson  1284.360
# 390                        has done tremendous scholarship on this,  1287.185
# 391                         but actually what Swenson shows is that  1290.220
# 392   there's never been significant\nexpansion of a welfare state,  1292.585
# 393                   even the European welfare\nstates by the way,  1297.380
# 394                              without significant at least tacit  1300.250
# 395                    and sometimes active\nsupport from business.  1302.640
# 396                             And part of it in the '30s and '40s  1307.620
# 397              was Keynesian thinking\nabout revising the economy  1311.670
# 398                                    or proto-Keynesian thinking.  1315.250
# 399                              The general theory didn't come out  1317.005
# 400                                until well after the Depression,  1319.520
# 401                                      but there were many people  1322.720
# 402                   making those kinds of\narguments at the time.  1323.726
# 403                                      But it was also political.  1329.115
# 404                                                It was this idea  1330.860
# 405                  that you want to give\nthe dispossessed people  1331.710
# 406                      who had been most harmed by the Depression  1335.940
# 407                                  a stake in the existing order.  1338.020
# 408         And similar arguments were\nmade in Britain and Europe.  1340.420
# 409                                   For instance, Ralph Miliband,  1345.870
# 410                             the father of Ed and David Miliband  1348.210
# 411                 was a political economist\nwho published a book  1351.090
# 412                              in the early '60s I believe it was  1354.883
# 413                        called "The Capitalist Industrial State"  1358.022
# 414                                              in which he argued  1363.396
# 415                 the welfare state is\ncapitalism's best friend.  1364.720
# 416                                               He was a Marxist,  1367.250
# 417                           well to the left even of Ed Miliband,  1368.549
# 418                        and he thought that this was a bad thing  1372.881
# 419                           because it was preventing the workers  1375.890
# 420                                     from becoming revolutionary  1378.070
# 421             because they had this stake\nin the existing order.  1379.770
# 422          And so this was the notion\nthat if you don't do this,  1384.550
# 423                          there's an alternative model out there  1391.252
# 424                                      vying for hearts and minds  1393.670
# 425                              and we'd better look out for that.  1395.580
# 426                       Once the alternative model has gone away,  1398.640
# 427                          once there's no longer a Soviet Union,  1402.770
# 428                       it's much easier to discount all of that.  1405.470
# 429                 It's much easier to say\nwell, let's, you know,  1408.830
# 430                                           you might not say it,  1412.020
# 431          but think move to the suburbs\nand build more prisons.  1412.960
# 432                                                It's not obvious  1416.490
# 433               that there's any reason\nof the sort that existed  1417.510
# 434               when there was a Communist\nalternative out there  1421.900
# 435               to continue to maintain\nexpensive welfare states  1425.270
# 436              that would require\nsubstantial levels of taxation  1431.090
# 437                         and maybe increasing levels of taxation  1434.100
# 438                            given the changes in the demography.  1436.868
# 439     So the short of it is that\nthose who had faith in the idea  1443.150
# 440                                    that the end of the Cold War  1448.402
# 441        was gonna be good for left\nof center parties were wrong  1450.230
# 442                                      and things have played out  1454.207
# 443                              quite differently since that time.  1455.891
# 444                                      So that's our first thing.  1459.238
# 445       But I want now to turn to\nsome more analytical thinking.  1461.421
# 446                            Let's put on my analytical hat here.  1466.918
# 447                                   Some more analytical thinking  1470.267
# 448                        about the logic of distributive politics  1472.430
# 449              because I think people\ndon't think clearly enough  1475.010
# 450                                   about just what that logic is  1479.180
# 451                       when they think about what's gonna happen  1482.425
# 452                               in different political scenarios.  1486.225
# 453                            So this is a famous picture of a hat  1490.030
# 454                      from the beginning of "The Little Prince,"  1494.039
# 455                                       Antoine de Saint-Exupery.  1496.560
# 456                                        And as you might recall,  1498.800
# 457                            it's the very beginning of the book.  1501.155
# 458                      He decides he wants to frighten the adults  1503.840
# 459                              and he's gonna frighten the adults  1507.048
# 460                                            by drawing a picture  1508.892
# 461                        of a boa constrictor eating an elephant.  1510.890
# 462                                                     So he does.  1514.780
# 463                                  And he's absolutely devastated  1516.620
# 464         when the adults say, "That's\na nice hat you've drawn."  1518.886
# 465                                               And he's furious.  1525.180
# 466        So he has to draw another\npicture showing the elephant,  1526.840
# 467                                                a sort of X-ray.  1530.150
# 468                                          But he's so despondent  1533.532
# 469             that he decides to abandon\nhis career as an artist  1536.410
# 470                 and instead become a\npilot which he duly does.  1540.130
# 471                    Now, one thing we can\nknow about this story  1544.930
# 472                   is that the adults he\nwas trying to frighten  1548.536
# 473                                             were not economists  1551.880
# 474                               because had they been economists,  1553.289
# 475                        he might have been able to frighten them  1556.210
# 476               with this picture because\ninstead of not seeing,  1558.550
# 477                                  instead of seeing it as a hat,  1561.985
# 478                                         they might have seen it  1563.885
# 479                        as a picture of the income distribution.  1565.200
# 480     And in particular, this feature\nof the income distribution  1568.124
# 481                                 which is that the median income  1573.900
# 482                                is always below the mean income.  1576.532
# 483                                              Why would that be?  1580.910
# 484                Why is the median income\nalways below the mean?  1581.940
# 485                                                            Yup.  1587.990
# 486                            - [Male Speaker] (mumbles) there are  1588.861
# 487                                     some extremely rich people.  1590.609
# 488                                      - Very rich people, right?  1593.070
# 489                                  The very rich people out here.  1594.520
# 490                                              In fact, you know,  1596.640
# 491                                    Gates, and Soros, and these,  1597.620
# 492                              they're probably on the other side  1599.063
# 493                of (mumbles) Street down\nthere actually, right?  1601.260
# 494                        And so that pulls up the average, right?  1603.780
# 495                                    So that means that in every,  1606.250
# 496                                                       you know,  1608.640
# 497                          obviously there's a cut off point here  1609.473
# 498   because there's some level below\nwhich people won't survive,  1611.520
# 499                   but the very rich people\npull up the average  1616.757
# 500      so there are always more people\nbelow the average income.  1620.080
# 501       And so this had for a long\ntime led political economists  1627.690
# 502       to think that politicians who\nare trying to win election  1633.140
# 503                             will be responsive the median voter  1640.280
# 504                          and there'd sorta be a kind of impetus  1642.430
# 505                                      to redistribute downwardly  1644.485
# 506                                 because politicians need votes,  1647.910
# 507                                       they need to get elected,  1650.260
# 508                                       and so they will do that.  1651.200
# 509           This median voter is gonna\nbe below the mean income.  1654.560
# 510                        And indeed, this is a very old argument.  1658.748
# 511                             So for example in the 19th century,  1662.130
# 512                        people like John Stuart Mill were afraid  1664.792
# 513            of expanding the franchise\nfor exactly this reason.  1667.420
# 514                                    And they came up with things  1670.400
# 515                  like giving two votes\nto university graduates  1671.630
# 516                                   as a way to sort of blunt it.  1675.090
# 517             And Karl Marx after he'd\nbeen disappointed in 1830  1677.400
# 518                                  when Communism had not arrived  1681.700
# 519                              and he'd been disappointed in 1848  1684.010
# 520                  when the revolutions\nhad not become Communist  1686.520
# 521       and he'd been disappointed\nin the Paris commune in 1871,  1688.890
# 522                              he and Engel started talking about  1692.958
# 523                            the parliamentary road to Socialism.  1695.070
# 524                              And this was exactly the same idea  1697.420
# 525        that maybe the workers would\ndo through the ballot box,  1699.097
# 526                       what they had not done at the barricades.  1702.980
# 527                                    And the 20th century's ideas  1705.670
# 528                  the median voter theorem\nwhich basically says  1707.750
# 529                 that politicians in\nsearch of the median voter  1711.992
# 530                      are gonna support downward redistribution.  1717.929
# 531   A very famous paper by two\npeople called Meltzer and Richard  1720.813
# 532                                      which I think is somewhere  1724.600
# 533                   in the recommended\nreadings on the syllabus.  1725.637
# 534                                           If not, it should be.  1728.060
# 535    And so the biggest puzzle of\n20th century political economy  1730.120
# 536                           is that this does not in fact happen.  1736.110
# 537                             That there's lots of redistribution  1738.740
# 538                               in Democratic capitalist systems,  1741.580
# 539                             but it's all kinds of distribution.  1745.222
# 540          It can be from urban to\nrural sectors of the economy.  1747.603
# 541                         It can be from one industry to another.  1754.790
# 542                          It can be done through food subsidies.  1758.341
# 543                            It can be done in all kinds of ways,  1761.140
# 544                                          but there's sometimes,  1762.950
# 545       there's regressive redistribution\nin capitalist systems.  1764.250
# 546            We'll talk later about the\nrepeal of the estate tax  1767.570
# 547              which is an example of\nusing the political system  1770.264
# 548                                to actually redistribute in ways  1773.296
# 549                                   that produce more inequality.  1776.052
# 550                                      And so that being the case  1778.275
# 551                         that the sort of standard expectations,  1780.984
# 552       the folk expectations that\nonce you've got majority rule  1783.720
# 553                                   with the universal franchise,  1788.290
# 554                               the poor are gonna soak the rich.  1790.100
# 555                                              Why wouldn't they?  1791.931
# 556                                               They've got less.  1793.595
# 557            They're gonna soak the\nrich, but it doesn't happen.  1794.920
# 558                          And so people have tried to understand  1797.430
# 559                                         why that doesn't happen  1799.420
# 560                          and there are basically two approaches  1801.663
# 561                                         to thinking about that.  1804.140
# 562                                   So, one would be to say well,  1805.840
# 563                                    I've got one dimension here.  1812.890
# 564                       The left wing party wants redistribution.  1814.700
# 565               The right wing party\ndoesn't want redistribution  1816.980
# 566               and the median voter's\ngonna want redistribution  1819.922
# 567                                     and so the right wing party  1825.830
# 568                           is gonna sorta be dragged to the left  1827.640
# 569       in search of the median voter\nor it's gonna lose, right?  1829.360
# 570                 But what if there's\nanother dimension as well?  1832.727
# 571                          What if there's a dimension like race?  1836.060
# 572                    So what if there's a\ndimension where people  1838.936
# 573                            have racially exclusionary attitudes  1842.450
# 1295     2.776
# 1296     3.340
# 1297     4.187
# 1298     3.855
# 1299     2.440
# 1300     4.820
# 1301     2.873
# 1302     3.097
# 1303     1.650
# 1304     2.030
# 1305     3.204
# 1306     2.126
# 1307     1.770
# 1308     3.510
# 1309     2.530
# 1310     1.821
# 1311     5.000
# 1312     4.664
# 1313     2.742
# 1314     2.094
# 1315     1.823
# 1316     3.098
# 1317     1.382
# 1318     1.223
# 1319     3.327
# 1320     2.986
# 1321     3.404
# 1322     2.390
# 1323     1.580
# 1324     1.700
# 1325     3.841
# 1326     3.772
# 1327     2.924
# 1328     3.670
# 1329     2.138
# 1330     1.462
# 1331     4.570
# 1332     4.490
# 1333     2.280
# 1334     2.420
# 1335     1.630
# 1336     2.526
# 1337     2.706
# 1338     3.568
# 1339     4.144
# 1340     2.215
# 1341     4.211
# 1342     1.921
# 1343     3.061
# 1344     4.768
# 1345     1.770
# 1346     3.673
# 1347     3.407
# 1348     1.762
# 1349     3.683
# 1350     5.000
# 1351     4.788
# 1352     4.053
# 1353     2.467
# 1354     3.016
# 1355     2.784
# 1356     5.000
# 1357     1.175
# 1358     3.138
# 1359     1.967
# 1360     2.358
# 1361     2.629
# 1362     4.985
# 1363     1.998
# 1364     3.114
# 1365     1.946
# 1366     4.620
# 1367     5.000
# 1368     4.156
# 1369     2.882
# 1370     3.960
# 1371     2.120
# 1372     2.050
# 1373     2.740
# 1374     3.000
# 1375     2.853
# 1376     3.008
# 1377     2.167
# 1378     1.356
# 1379     2.417

# %%
' '.join(transcript['text'])
# Out:
# '- Okay, so today, we\'re talking about the\nresurgent right in the West. Let\'s get fix our intuitions with a little walk down memory lane. - [Ronald Reagan] In Chicago, they found a woman who holds the record. She used 80 names, 30\naddresses, 15 telephone numbers to collect food stamps, social security, veteran\'s benefits for four non-existent deceased veterans husbands\nas well as welfare. Her tax free cash income alone has been running $150,000 a year. - So that was Ronald Reagan running for the Republican nomination against Gerald Ford in 1976, which he was unsuccessful, and that\'s his famous\nwelfare queens speech which would become if things had been able\nto go viral in those days, it did the paper equivalent of going viral and it represented this frontal assault on the welfare state, on what might be more broadly referred to as the postwar consensus\nthat had prevailed in almost all of the capitalist\ndemocracies since the 1950s. In the US, it went by the\nname of the Great Society ushered in by Lyndon Johnson which was not only the\ncivil rights legislation, but the creation of Medicare, considerable expansion of many components of the welfare state. In Britain, it was of course\nthe postwar government of Clement Attlee voted\ninto office in 1945 that put into place the major elements of the British welfare state. And in many of the\nEuropean social democracies as they came to be called, we got countries that were\nmarked by strong welfare and other forms of social protections such as health insurance, unemployment insurance, pensions, progressive tax systems, a lot of redistribution\nthrough the tax system, much more steeply progressive tax systems than in any of those countries today. And it\'s important to say that the support for\nthis postwar consensus was substantially bipartisan. So for example, in Britain when the Conservatives under Churchill came back into power in 1951, many people said, "Oh,\nthey\'re gonna roll back "everything that labor has done." Not a bit of it actually. They even expanded it. And through much of the\n1950s, \'60s, and \'70s, you saw in most countries\nthe recognition of a kind of what seemed to be a\nsubstantially bipartisan support for this welfare state. In the US, in the Nixon Administration, of course, there was some\npressure for lower taxes, but still, much of the\nwelfare state was preserved and in some ways it was even expanded. They got things like, which I\'ll be talking\nabout later in the course, such as universal basic income. Nixon has supported what he\ncalled a negative income tax, a kind of refundable tax credit. We\'ve ended up getting something\nthat\'s a cousin of that. In Europe in countries like Germany where they have coalition governments, in the \'60s and \'70s, they were basically dominated\nby the social democrats. First, Willy Brandt,\nand then Helmut Schmidt. After in the early \'80s, for reasons we\'ll be\ntalking about next time, the social democrats got weaker and Helmut Kohl\'s Conservatives took over. But it was still, there was very substantial support for European social democracy\nacross the political spectrum. For example, in the \'60s\nand \'70s in France and Italy where Communist parties\nhad been very strong and had traditionally been more Stalinist like Communist parties, we had the advent of Euro-Communism. What was Euro-Communism? Well, one feature of it was that it was denounced\nby the Soviet Union as revisionist deviationism. And the other was that the standing joke in Italy in the 1970s\nwas how can you tell that which is the Communist\npolitician in parliament? How do you tell the Communist\nfrom the other politicians? And the answer was because\nthey have more expensive suits. So the Euro-Communists\nagain stop pushing this idea that social democracy was a way station on the way to Soviet style Communism and instead was a particular form of political and social\norganization that had come to stay. And it was seen to be as I said,  ...

# %%
df_transcripts = df_transcripts.replace(r'\n',' ', regex=True)

# %%
df_transcripts.head(20)
# Out:
#                                                         text   start  \
# 0                             - Hello everybody and welcome.   8.060
# 1                                    How is everybody today?  10.720
# 2                                                     Great.  13.404
# 3                Well, I'm delighted to have the opportunity  14.320
# 4                          to be giving the DeVane Lectures.  17.860
# 5                  And the DeVane Lectures, as you can tell,  20.780
# 6                    from looking around you double as being  23.640
# 7                           a regular Yale course for credit  27.470
# 8                          that students can take for credit  30.780
# 9          and lectures that are open to the general public.  32.700
# 10  These lectures are going to deal with power and politics  37.610
# 11                    in today's world and by today's world,  41.440
# 12                    I'm gonna mean the 30 years since 1989  44.900
# 13                           and the 30 years since 1989 are  50.410
# 14             and have been an incredibly tumultuous period  53.950
# 15                                     of very great change.  61.440
# 16                               And that's for xxx unusual.  63.350
# 17  For instance, if you compare it to the previous 40 years  68.280
# 18           in most of the advanced capitalist democracies,  71.440
# 19                  they were a period of relative stability  75.250
#
#     duration     video_id
# 0      2.660  BDqvzFY72mg
# 1      1.613  BDqvzFY72mg
# 2      0.916  BDqvzFY72mg
# 3      3.540  BDqvzFY72mg
# 4      2.920  BDqvzFY72mg
# 5      2.860  BDqvzFY72mg
# 6      3.830  BDqvzFY72mg
# 7      3.310  BDqvzFY72mg
# 8      1.920  BDqvzFY72mg
# 9      3.673  BDqvzFY72mg
# 10     3.830  BDqvzFY72mg
# 11     3.460  BDqvzFY72mg
# 12     5.000  BDqvzFY72mg
# 13     3.540  BDqvzFY72mg
# 14     4.003  BDqvzFY72mg
# 15     1.910  BDqvzFY72mg
# 16     4.083  BDqvzFY72mg
# 17     3.160  BDqvzFY72mg
# 18     3.810  BDqvzFY72mg
# 19     3.160  BDqvzFY72mg

# %%
df_transcripts.to_csv('transcripts.csv', index=False)
